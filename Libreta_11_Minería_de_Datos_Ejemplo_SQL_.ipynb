# %% [markdown]
# # Libreta 10 - Uso de SQL y LLMs para creación de recomendaciones Parte 1
#
# **Profesor:**  Dr. Farid Krayem Pineda
#
# **Materia:**  Minería de Datos
#
# **Universidad Anáhuac Puebla**
#
# ---

# %%
# Instalamos PyMySQL para compatibilidad entre Python y SQL

# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1

# %%
# Instalación de librerías

import pandas as pd
import xml.etree.ElementTree as ET
import requests
from google import genai
from google.colab import userdata
import time
import pymysql
import random

# %%
# Aquí usa tu API KEY de Gemini

api_key_gemini = userdata.get('api_key_gemini_gmail')

# %%
## Creamos un dataframe a partir del sitemap de productos

# URL del sitemap
sitemap_url = "https://fredzapaterias.com.mx/sitemap_products_1.xml?from=4604151169112&to=9125506482405"

# Descargar el sitemap
response = requests.get(sitemap_url)
response.raise_for_status()

# Parsear el contenido
root = ET.fromstring(response.content)

# Definir namespaces
namespaces = {
    "ns": "http://www.sitemaps.org/schemas/sitemap/0.9",
    "image": "http://www.google.com/schemas/sitemap-image/1.1"
}

# Crear listas para guardar datos
productos = []
imagenes = []

# Extraer información
for url in root.findall("ns:url", namespaces):
    image_title = url.find("image:image/image:title", namespaces)
    image_loc = url.find("image:image/image:loc", namespaces)

    if image_title is not None and image_loc is not None:
        productos.append(image_title.text)
        imagenes.append(image_loc.text)

# Crear el DataFrame
programs_df = pd.DataFrame({
    "Producto": productos,
    "Imagen": imagenes
})

programs_df
# Out:
#                                                Producto  \
# 0           Sandalias de Piso para Hombre Caray FOREVER
# 1     Zapatos Hombre Sandalia De Piso Para Playa Car...
# 2     Zapatos Bebés Bota De Niña Con Hebilla Sandy 5062
# 3     Zapatos Bebés Bota De Niña Casual Con Hebilla ...
# 4     Zapatos Bebés Bota De Niño Casual Con Agujetas...
# ...                                                 ...
# 1961  Tenis Casuales con Agujetas para Hombre Puma 3...
# 1962  Tenis Casuales con Agujetas para Hombre Puma 3...
# 1963  Tenis Deportivos con Agujetas para Hombre Reeb...
# 1964  Tenis Casuales con Agujetas para Hombre Skeche...
# 1965          Sandalias Casuales para Niños Yuyin 25110
#
#                                                  Imagen
# 0     https://cdn.shopify.com/s/files/1/0285/8585/30...
# 1     https://cdn.shopify.com/s/files/1/0285/8585/30...
# 2     https://cdn.shopify.com/s/files/1/0285/8585/30...
# 3     https://cdn.shopify.com/s/files/1/0285/8585/30...
# 4     https://cdn.shopify.com/s/files/1/0285/8585/30...
# ...                                                 ...
# 1961  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 1962  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 1963  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 1964  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 1965  https://cdn.shopify.com/s/files/1/0285/8585/30...
#
# [1966 rows x 2 columns]

# %%
## Guardamos los 15 primeros resultados de los productos ##

prod_fin_df = programs_df.head(15)
prod_fin_df
# Out:
#                                              Producto  \
# 0         Sandalias de Piso para Hombre Caray FOREVER
# 1   Zapatos Hombre Sandalia De Piso Para Playa Car...
# 2   Zapatos Bebés Bota De Niña Con Hebilla Sandy 5062
# 3   Zapatos Bebés Bota De Niña Casual Con Hebilla ...
# 4   Zapatos Bebés Bota De Niño Casual Con Agujetas...
# 5   Zapatos Bebés Bota De Niño Casual Con Velcro S...
# 6   Botas Industriales con Casquillo para Hombre R...
# 7           Botas Vaqueras Para Hombre Rio Grande 291
# 8   Bota Industrial Con Agujetas Y Casquillo para ...
# 9   Zapatos Hombre De Vestir Con Agujetas Quirelli...
# 10  Zapatos Bebés Bota De Niña Casual Con Velcro S...
# 11  Zapatos Bebés Bota De Niño Casual Con Velcro S...
# 12        Sandalias de Playa para Niños Caray FOREVER
# 13  Zapatos Niños Sandalia Casual Con Velcro Coque...
# 14  Zapatos Niños Sandalia Casual Con Velcro Coque...
#
#                                                Imagen
# 0   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 1   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 2   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 3   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 4   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 5   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 6   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 7   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 8   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 9   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 10  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 11  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 12  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 13  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 14  https://cdn.shopify.com/s/files/1/0285/8585/30...

# %%
client = genai.Client(api_key=api_key_gemini)

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Crea un haiku sobre minería de datos. ",
)

print(response.text)
# Out:
# Datos desenterrados,
# Conocimiento se encuentra brillante,
# Patrones revelados.

# %%
def respuesta_chat(rol,prompt):
  response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=rol + " " + prompt,
  )

  respuesta = response.text

  return respuesta

# %%
respuesta_chat("Eres un poeta mexicano","Tu tarea es hacer un poema de 20 palabras sobre los mayas.")
# Out:
# 'Claro, aquí te va:\n\nEn selva verde, pirámides de piedra,\nsabios mayas, estrellas lejanas,\ncalendario eterno, un eco ancestral.\n'

# %%
## Usamos Google Gemini para generar las descripciones del producto

# Inicializar cliente
client = genai.Client(api_key=api_key_gemini)

# Crear lista para las descripciones
descripciones = []

# Generar descripciones con control de rate limit
for idx, producto in enumerate(prod_fin_df["Producto"]):
    if idx > 0 and idx % 14 == 0:
        time.sleep(60)  # Esperar 60 segundos después de 14 solicitudes

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=f"Genera una descripción de producto de aproximadamente 70 palabras sobre el producto: {producto}. El tono debe ser claro y persuasivo."
    )
    descripciones.append(response.text)

# Agregar la columna al DataFrame
prod_fin_df["Descripción"] = descripciones

prod_fin_df
# Out:
# <ipython-input-9-a3f0c7caf994>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod_fin_df["Descripción"] = descripciones
#                                              Producto  \
# 0         Sandalias de Piso para Hombre Caray FOREVER
# 1   Zapatos Hombre Sandalia De Piso Para Playa Car...
# 2   Zapatos Bebés Bota De Niña Con Hebilla Sandy 5062
# 3   Zapatos Bebés Bota De Niña Casual Con Hebilla ...
# 4   Zapatos Bebés Bota De Niño Casual Con Agujetas...
# 5   Zapatos Bebés Bota De Niño Casual Con Velcro S...
# 6   Botas Industriales con Casquillo para Hombre R...
# 7           Botas Vaqueras Para Hombre Rio Grande 291
# 8   Bota Industrial Con Agujetas Y Casquillo para ...
# 9   Zapatos Hombre De Vestir Con Agujetas Quirelli...
# 10  Zapatos Bebés Bota De Niña Casual Con Velcro S...
# 11  Zapatos Bebés Bota De Niño Casual Con Velcro S...
# 12        Sandalias de Playa para Niños Caray FOREVER
# 13  Zapatos Niños Sandalia Casual Con Velcro Coque...
# 14  Zapatos Niños Sandalia Casual Con Velcro Coque...
#
#                                                Imagen  \
# 0   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 1   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 2   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 3   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 4   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 5   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 6   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 7   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 8   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 9   https://cdn.shopify.com/s/files/1/0285/8585/30...
# 10  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 11  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 12  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 13  https://cdn.shopify.com/s/files/1/0285/8585/30...
# 14  https://cdn.shopify.com/s/files/1/0285/8585/30...
#
#                                           Descripción
# 0   Disfruta la comodidad y el estilo atemporal co...
# 1   Prepárate para la playa con las sandalias Cara...
# 2   ¡Prepárate para adorar las Botas Sandy 5062! E...
# 3   ¡Prepárate para robar corazones con las botas ...
# 4   ¡Dale a tu pequeño aventurero sus primeros pas...
# 5   ¡Prepárate para la aventura con las Botas Sand...
# 6   Domina cualquier terreno con las Botas Industr...
# 7   Domina el estilo vaquero con las Botas Rio Gra...
# 8   Domina el trabajo duro con la Bota Industrial ...
# 9   Eleva tu estilo con los zapatos de vestir Quir...
# 10  ¡A tu pequeña le encantarán las Botas Sandy 56...
# 11  ¡Dale a tus pequeños el estilo y la comodidad ...
# 12  ¡Diversión sin fin en la playa con las Sandali...
# 13  ¡Prepárate para la aventura con las sandalias ...
# 14  ¡Prepárate para la aventura con las sandalias ...

# %%
## Impresión de un registro para validación

# Seleccionar un índice aleatorio
random_index = random.randint(0, len(prod_fin_df) - 1)

# Obtener la descripción correspondiente
descripcion_prueb = prod_fin_df["Descripción"].iloc[random_index]

# Imprimir resultados con mejor formato
print("="*50)
print(f"📄 Registro seleccionado: {random_index}")
print(f"📝 Número de palabras: {len(descripcion_prueb.split())}")
print("\nDescripción:\n")
print(descripcion_prueb)
print("="*50)
# Out:
# ==================================================
# 📄 Registro seleccionado: 2
# 📝 Número de palabras: 78
#
# Descripción:
#
# ¡Prepárate para adorar las Botas Sandy 5062! Estas adorables botas para bebé niña combinan estilo y comodidad a la perfección. Fabricadas con materiales suaves y duraderos, cuentan con un cierre de hebilla que asegura un ajuste perfecto para esos piecitos en crecimiento. Su diseño clásico y femenino las hace ideales para cualquier ocasión, desde paseos en el parque hasta fiestas especiales. ¡Dale a tu pequeña el estilo y la comodidad que se merece con las Botas Sandy 5062!
#
# ==================================================

# %%
## Probar la conexión con la base de datos.

pass_db = userdata.get('pass_db_anahua')

# Configura los detalles de conexión a la base de datos
host = "35.215.110.77"
puerto = 3306
usuario = "ugu1kvcishvbx"
contraseña = pass_db
base_de_datos = "dboewuclpuqgcr"

# Intenta conectarte a la base de datos
try:
    conexion = pymysql.connect(
        host=host,
        user=usuario,
        password=contraseña,
        database=base_de_datos
    )
    print("Conexión exitosa a la base de datos.")

    # No olvides cerrar la conexión cuando hayas terminado
    conexion.close()

except pymysql.Error as e:
    print("Error al conectar a la base de datos:", e)
# Out:
# Conexión exitosa a la base de datos.

# %%
# Configura los detalles de conexión a la base de datos
host = "35.215.110.77"
puerto = 3306
usuario = "ugu1kvcishvbx"
contraseña = pass_db
base_de_datos = "dboewuclpuqgcr"

# Conectarse a la base de datos
try:
    conexion = pymysql.connect(
        host=host,
        user=usuario,
        password=contraseña,
        database=base_de_datos
    )
    cursor = conexion.cursor()

    # Verificar si existe la tabla
    cursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_schema = %s
        AND table_name = 'prueba_productos'
    """, (base_de_datos,))

    if cursor.fetchone()[0] == 1:
        cursor.execute("DROP TABLE prueba_productos")
        print("Tabla 'prueba_productos' eliminada.")

    # Crear la tabla
    cursor.execute("""
        CREATE TABLE prueba_productos (
            id INT AUTO_INCREMENT PRIMARY KEY,
            Producto TEXT,
            Imagen TEXT,
            Descripcion TEXT
        )
    """)
    print("Tabla 'prueba_productos' creada.")

    # Insertar datos de prod_fin_df
    for _, row in prod_fin_df.iterrows():
        cursor.execute("""
            INSERT INTO prueba_productos (Producto, Imagen, Descripcion)
            VALUES (%s, %s, %s)
        """, (row["Producto"], row["Imagen"], row.get("Descripción", "")))

    conexion.commit()
    print("Datos insertados correctamente.")

    conexion.close()

except pymysql.Error as e:
    print("Error al conectar o manipular la base de datos:", e)
# Out:
# Tabla 'prueba_productos' eliminada.
# Tabla 'prueba_productos' creada.
# Datos insertados correctamente.

# %%
# Conectarse y consultar
try:
    conexion = pymysql.connect(
        host=host,
        user=usuario,
        password=contraseña,
        database=base_de_datos
    )
    cursor = conexion.cursor()

    # Consultar todos los registros
    cursor.execute("SELECT * FROM prueba_productos")
    resultados = cursor.fetchall()

    for fila in resultados:
        print(fila)

    conexion.close()

except pymysql.Error as e:
    print("Error al conectar o consultar la base de datos:", e)
# Out:
# (1, 'Sandalias de Piso para Hombre Caray FOREVER', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/zapatos-hombre-sandalias-caray-forever-cafe-lateral.jpg?v=1741298765', 'Disfruta la comodidad y el estilo atemporal con las Sandalias de Piso para Hombre Caray FOREVER. Fabricadas con materiales duraderos y un diseño ergonómico, estas sandalias te brindan soporte y frescura durante todo el día. Ideales para la playa, la piscina o simplemente relajarte en casa, las FOREVER son la opción perfecta para el hombre moderno que busca confort sin sacrificar la elegancia. ¡Pisa con confianza y estilo con Caray FOREVER!\n')
# (2, 'Zapatos Hombre Sandalia De Piso Para Playa Caray Georgia', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/caray-georgia-cafe.jpg?v=1591168722', 'Prepárate para la playa con las sandalias Caray Georgia. Diseñadas para la comodidad y el estilo, estas sandalias de piso para hombre son perfectas para tus aventuras veraniegas. Fabricadas con materiales duraderos y un diseño moderno, te ofrecen la combinación ideal de soporte y frescura. ¡Siente la libertad en cada paso con Caray Georgia y disfruta del sol con total confianza! Ideales para caminar por la arena o relajarte en la piscina.\n')
# (3, 'Zapatos Bebés Bota De Niña Con Hebilla Sandy 5062', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/zapatos-ninas-zapatos-sandy-5062-blanco-oso1-lateral.jpg?v=1648155912', '¡Prepárate para adorar las Botas Sandy 5062! Estas adorables botas para bebé niña combinan estilo y comodidad a la perfección. Fabricadas con materiales suaves y duraderos, cuentan con un cierre de hebilla que asegura un ajuste perfecto para esos piecitos en crecimiento. Su diseño clásico y femenino las hace ideales para cualquier ocasión, desde paseos en el parque hasta fiestas especiales. ¡Dale a tu pequeña el estilo y la comodidad que se merece con las Botas Sandy 5062!\n')
# (4, 'Zapatos Bebés Bota De Niña Casual Con Hebilla Sandy 5612', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/zapatos-ninas-zapatos-sandy-5612-c784-fiusha-piel-lateral.jpg?v=1696890621', '¡Prepárate para robar corazones con las botas Sandy 5612! Estas adorables botitas casuales para niña combinan estilo y comodidad a la perfección. Fabricadas con materiales suaves y duraderos, protegerán los pies de tu pequeña mientras luce un look encantador. Su diseño con hebilla ajustable asegura un ajuste perfecto, mientras que su suela flexible le permite moverse con total libertad. ¡Perfectas para cualquier ocasión, desde juegos en el parque hasta reuniones familiares! ¡Dale a tu princesa un toque de estilo con las Sandy 5612!\n')
# (5, 'Zapatos Bebés Bota De Niño Casual Con Agujetas Sandy 5031', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/zapatos-ninos-zapatos-sandy-5031-blanco-oso1-lateral.jpg?v=1648165861', '¡Dale a tu pequeño aventurero sus primeros pasos con estilo! Las botas Sandy 5031 son el calzado perfecto para bebés y niños pequeños. Su diseño casual con agujetas ofrece un ajuste seguro y cómodo para explorar el mundo. Fabricadas con materiales suaves y resistentes, brindan soporte y protección a sus piececitos en cada paso. ¡Ideales para jugar, gatear y caminar con confianza! Elige Sandy 5031 y asegura un look adorable y el confort que tu bebé merece.\n')
# (6, 'Zapatos Bebés Bota De Niño Casual Con Velcro Sandy 5247', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/sandy-5247-chocolate.jpg?v=1604987919', '¡Prepárate para la aventura con las Botas Sandy 5247! Diseñadas para los pequeños exploradores, estas botas casuales ofrecen comodidad y estilo en cada paso. Fáciles de poner y quitar gracias a su práctico velcro, son perfectas para el día a día. Fabricadas con materiales suaves y duraderos, brindan el soporte que necesitan sus pies en crecimiento. ¡Que nada detenga su diversión con las Botas Sandy! Disponibles en varios colores.\n')
# (7, 'Botas Industriales con Casquillo para Hombre Rio Grande WP-05', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/zapatos-hombres-bota-rio-grande-WP-05-chocolate-lateral.jpg?v=1646682702', 'Domina cualquier terreno con las Botas Industriales Rio Grande WP-05. Diseñadas para la máxima protección y confort, estas botas para hombre cuentan con un casquillo de acero resistente a impactos y compresión. Su construcción impermeable te mantiene seco en condiciones adversas, mientras que la suela antideslizante proporciona tracción segura. Ideales para trabajos pesados, construcción o cualquier actividad exigente. Invierte en la seguridad y durabilidad que necesitas con Rio Grande.\n')
# (8, 'Botas Vaqueras Para Hombre Rio Grande 291', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/zapatos-hombres-botas-rio-grande-291-miel-crazy-lateral.jpg?v=1671639246', 'Domina el estilo vaquero con las Botas Rio Grande 291. Fabricadas con cuero de alta calidad y un diseño clásico, estas botas son la combinación perfecta de durabilidad y elegancia. Ideales para el trabajo duro o una noche en la ciudad, te brindan comodidad y soporte durante todo el día. Su suela resistente te asegura tracción en cualquier terreno. ¡Siente la tradición y la confianza en cada paso con Rio Grande!\n')
# (9, 'Bota Industrial Con Agujetas Y Casquillo para Hombre Swissbrand 510701', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/files/zapatos-hombre-bota-swissbrand-510701-negro.jpg?v=1723563655', 'Domina el trabajo duro con la Bota Industrial Swissbrand 510701. Diseñada para el hombre moderno que exige protección y confort, esta bota con agujetas y casquillo ofrece seguridad superior en entornos exigentes. Fabricada con materiales duraderos y un diseño ergonómico, proporciona soporte y estabilidad durante toda la jornada.  Invierte en la calidad y tranquilidad que te brinda Swissbrand. ¡Siente la diferencia en cada paso!\n')
# (10, 'Zapatos Hombre De Vestir Con Agujetas Quirelli 88402', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/zapatos-hpmbre-flexi-88402-negro-lateral.jpg?v=1679106349', 'Eleva tu estilo con los zapatos de vestir Quirelli 88402. Confeccionados para el hombre moderno que aprecia la elegancia clásica, estos zapatos con agujetas ofrecen un ajuste cómodo y seguro. Su diseño sofisticado y materiales de alta calidad garantizan durabilidad y un look impecable. Perfectos para la oficina, eventos especiales o cualquier ocasión que exija distinción. ¡Quirelli 88402: la elección ideal para un caballero con clase!\n')
# (11, 'Zapatos Bebés Bota De Niña Casual Con Velcro Sandy 5642', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/files/zapatos-bebes-bota-nina-sandy-5642-negro-lateral.jpg?v=1713896468', '¡A tu pequeña le encantarán las Botas Sandy 5642! Perfectas para sus primeras aventuras, estas botas casuales para niña ofrecen comodidad y estilo. Su cierre de velcro facilita el calzado, incluso para las más independientes. Fabricadas con materiales suaves y duraderos, garantizan protección y soporte en cada paso. ¡Ideales para el día a día y para completar cualquier look adorable! Haz que sus primeros pasos sean seguros y a la moda con Sandy.\n')
# (12, 'Zapatos Bebés Bota De Niño Casual Con Velcro Sandy 5038', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/zapatos-ninos-zapatos-sandy-5038-negro-oso2-lateral.jpg?v=1648166012', '¡Dale a tus pequeños el estilo y la comodidad que merecen con las Botas Sandy 5038! Perfectas para sus primeras aventuras, estas botas casuales para bebé combinan diseño y funcionalidad. Fabricadas con materiales suaves y resistentes, cuentan con un práctico cierre de velcro que facilita su colocación y ajuste. Disponibles en una variedad de colores adorables, son la opción ideal para mantener los pies de tu bebé protegidos y con estilo en cada paso. ¡Un imprescindible para su guardarropa!\n')
# (13, 'Sandalias de Playa para Niños Caray FOREVER', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/caray-forever-negro_e132e532-77e4-4006-9b43-5bf087a0a620.jpg?v=1652207476', '¡Diversión sin fin en la playa con las Sandalias Caray FOREVER para niños! Fabricadas con materiales duraderos y cómodos, estas sandalias son perfectas para jugar en la arena, chapotear en el agua y explorar la costa. Su diseño vibrante y ajuste seguro garantizan horas de aventura despreocupada. ¡Deja que sus pies exploren el mundo con Caray FOREVER! Ideales para la playa, la piscina y cualquier actividad al aire libre.\n')
# (14, 'Zapatos Niños Sandalia Casual Con Velcro Coqueta Y Audaz 168003-F', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/zapatos-ninos-sandalias-coqueta-y-audaz-168003-F-cafe-piel-lateral.jpg?v=1649109159', '¡Prepárate para la aventura con las sandalias 168003-F! Perfectas para niñas coquetas y audaces, estas sandalias casuales ofrecen comodidad y estilo gracias a su diseño moderno y cierre de velcro fácil de usar. Ideales para jugar, pasear o simplemente disfrutar del día, proporcionan un ajuste seguro y una pisada suave. ¡Dale a sus pies la libertad que merecen con estas sandalias irresistibles!\n')
# (15, 'Zapatos Niños Sandalia Casual Con Velcro Coqueta Y Audaz 168003-M', 'https://cdn.shopify.com/s/files/1/0285/8585/3016/products/zapatos-ninos-sandalias-coqueta-y-audaz-168003-M-cafe-claro-lateral.jpg?v=1652208205', '¡Prepárate para la aventura con las sandalias Coqueta y Audaz 168003-M! Diseñadas para pequeños exploradores, estas sandalias casuales combinan comodidad y estilo. Su práctico cierre de velcro permite un ajuste perfecto y fácil de poner y quitar. Ideales para el juego diario, garantizan seguridad y frescura en cada paso. ¡Un calzado resistente y moderno que complementará cualquier outfit infantil!\n')

# %%
# Configura los detalles de conexión a la base de datos
host = "35.215.110.77"
puerto = 3306
usuario = "ugu1kvcishvbx"
contraseña = pass_db
base_de_datos = "dboewuclpuqgcr"

# Conectarse y consultar columnas
try:
    conexion = pymysql.connect(
        host=host,
        user=usuario,
        password=contraseña,
        database=base_de_datos
    )
    cursor = conexion.cursor()

    # Consultar solo las columnas de la tabla
    cursor.execute("""
        SELECT COLUMN_NAME
        FROM information_schema.columns
        WHERE table_schema = %s
        AND table_name = 'prueba_productos'
    """, (base_de_datos,))

    columnas = cursor.fetchall()

    for columna in columnas:
        print(columna[0])

    conexion.close()

except pymysql.Error as e:
    print("Error al conectar o consultar columnas de la base de datos:", e)
# Out:
# id
# Producto
# Imagen
# Descripcion

# %%
# Vamos a meter un valor de forma manual

# Configura los detalles de conexión a la base de datos
host = "35.215.110.77"
puerto = 3306
usuario = "ugu1kvcishvbx"
contraseña = pass_db
base_de_datos = "dboewuclpuqgcr"

# Datos a insertar manualmente
producto = "Bicicleta de Montaña Minería de Datos"
imagen = "https://elektra.vtexassets.com/arquivos/ids/9531890-1200-auto?v=638700586835800000&width=1200&height=auto&aspect=true"
descripcion = "Experimenta la aventura con la Bicicleta de Minería de Datos. Diseñada para conquistar terrenos desafiantes, su cuadro resistente y suspensión delantera absorben los impactos, brindándote comodidad y control. Sus 21 velocidades te permiten adaptarte a cualquier pendiente, mientras que sus frenos de disco te garantizan seguridad en cada descenso. ¡Libera tu espíritu aventurero y explora nuevos horizontes con la Ranger R27.5!"

# Conectarse y agregar registro
try:
    conexion = pymysql.connect(
        host=host,
        user=usuario,
        password=contraseña,
        database=base_de_datos
    )
    cursor = conexion.cursor()

    cursor.execute("""
        INSERT INTO prueba_productos (Producto, Imagen, Descripcion)
        VALUES (%s, %s, %s)
    """, (producto, imagen, descripcion))

    conexion.commit()
    print("Registro agregado correctamente.")

    conexion.close()

except pymysql.Error as e:
    print("Error al conectar o insertar el registro:", e)
# Out:
# Registro agregado correctamente.

# %%
# Configura los detalles de conexión a la base de datos
host = "35.215.110.77"
puerto = 3306
usuario = "ugu1kvcishvbx"
contraseña = pass_db
base_de_datos = "dboewuclpuqgcr"

# Conectarse y eliminar el producto
try:
    conexion = pymysql.connect(
        host=host,
        user=usuario,
        password=contraseña,
        database=base_de_datos
    )
    cursor = conexion.cursor()

    # Eliminar el producto específico
    cursor.execute("""
        DELETE FROM prueba_productos
        WHERE Producto = %s
    """, ("Bicicleta de Montaña Ranger R27.5 21V Gris",))

    conexion.commit()
    print("Producto eliminado correctamente.")

    conexion.close()

except pymysql.Error as e:
    print("Error al conectar o eliminar el producto:", e)
# Out:
# Producto eliminado correctamente.

# %% [markdown]
# ## Revisa tu resultado en:
#
# [Anáhuac Moda](https://mercabits.com/dev/anahuac-moda/)
